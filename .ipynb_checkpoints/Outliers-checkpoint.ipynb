# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# define our dataset
dataset = [10,11,12,13,14,15,16,17,18,20,22,24,25,26,30,34,32,33,40,45,50,55,60,90,120,180]

# %%
sns.histplot(dataset,color='y',kde=True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# z score
outliers = []
# function to take data as argument and return possible outliers
def detect_outliers(data):
    threshold=2 # 3 std deviation
    mean = np.mean (data)
    std = np.std(data)
    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score)>threshold:
            outliers.append(i)
    return outliers

# %%
detect_outliers(dataset)
# Out:
# [120, 180]

# %%
dataset = sorted (dataset)

# %%
q1,q2,q3 = np.percentile(dataset,[25,50,75])

# %%
print(q1,q2,q3)
# Out:
# 16.25 25.5 43.75

# %%
iqr=q3*q1
print(iqr)
# Out:
# 710.9375

# %%
# find the lower fence and higher fence
lower_fence = q1-(1.5*iqr)
higher_fence=q3+(1.5*iqr)

# %%
print(lower_fence,higher_fence)
# Out:
# -1050.15625 1110.15625

# %%
# remove the outliers which doesnot belongs to lower-->higher fence range
outliers=[]
for item in dataset:
    if item<lower_fence or item>higher_fence:
        outliers.append(item)

# %%
print(outliers)
# Out:
# []

# %%
sns.boxplot(dataset)
# Out:
# C:\Users\Nikita Uprety\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
for item in outliers:
    dataset.remove(item)

# %%
sns.boxplot(dataset)
# Out:
# C:\Users\Nikita Uprety\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
